# %% [markdown]
# # Data Sets

# %%
using Plots

include("DataSets.jl")
using .DataSets

# %% [markdown]
# ## MNIST

# %%
dataset_mnist = prepare_mnist(get_mnist("data/mnist"))
X_mnist_train, y_mnist_train, X_mnist_test, y_mnist_test = dataset_mnist
size(X_mnist_train), size(y_mnist_train)
# Out:
# ((32, 32, 1, 60000), (60000,))

# %%
i_mnist = 16
y_mnist_train[i_mnist]
# Out:
# 7

# %%
input_mnist = X_mnist_train[:, :, 1, i_mnist]
image_mnist = Gray.(input_mnist)
image_mnist'
# Out:
# 32×32 adjoint(::Array{Gray{Float32},2}) with eltype Gray{Float32}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  ⋮                                       ⋱
# ...

# %%
plot(image_mnist')

# %%
unique(y_mnist_train)
# Out:
# 10-element Vector{Int64}:
#   5
#  10
#   4
#   1
#   9
#   2
#   3
#   6
#   7
#   8

# %% [markdown]
# ## SVHN

# %%
dataset_svhn = prepare_svhn(get_svhn("data/svhn"))
X_svhn_train, y_svhn_train, X_svhn_test, y_svhn_test = dataset_svhn
size(X_svhn_train), size(y_svhn_train)
# Out:
# ((32, 32, 1, 73257), (73257,))

# %%
i_svhn = 128
y_svhn_train[i_svhn]
# Out:
# 1

# %%
input_svhn = X_svhn_train[:, :, 1, i_svhn]
plot(Gray.(input_svhn)')

# %%
unique(y_svhn_train)
# Out:
# 10-element Vector{Int64}:
#   1
#   9
#   2
#   3
#   5
#   8
#   7
#   4
#   6
#  10
